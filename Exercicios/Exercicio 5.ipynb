# %% [markdown]
# # Exercicio 5

# %%
# Exercicio 1
num1 = int(input("Digite um numero"))
num2 = int(input("Digite outro numero"))
if num1 == 0 or num2 == 0:
    raise Exception("Erro: Divisão por zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 num2 = int(input("Digite outro numero"))
#       4 if num1 == 0 or num2 == 0:
# ----> 5     raise Exception("Erro: Divisão por zero")
#
# Exception: Erro: Divisão por zero

# %%
# Exercicio 2
lista = [11, 11, 11]
indice = int(input("Digite um indice da lista, 0-2"))
if indice > len(lista)-1:
    raise Exception("Numero fora do indice")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 indice = int(input("Digite um indice da lista, 0-2"))
#       4 if indice > len(lista) -1:
# ----> 5     raise Exception("Numero fora do indice")
#
# Exception: Numero fora do indice

# %%
# Exercicio 2
lista = [11, 11, 11]
indice = int(input("Digite um indice da lista, 0-2"))
try:
    print(lista[indice])
except:
    raise Exception("numero fora dos indices")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 5
#       4 try:
# ----> 5     print(lista[indice])
#       6 except:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5     print(lista[indice])
#       6 except:
# ----> 7     raise Exception("numero fora dos indices")
#
# Exception: numero fora dos indices

# %%
# Exercicio 3
teste = float(input("Teste"))
if type(teste) != int:
    raise Exception("Numero nao é inteiro")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 teste = float(input("Teste"))
#       3 if type(teste) != int:
# ----> 4     raise Exception("Numero nao é inteiro")
#
# Exception: Numero nao é inteiro

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %%
# Exercicio 4
try:
    num1 = int(input("Digite um numero"))
    num2 = int(input("Digite outro numero"))
except ZeroDivisionError:
    print("Não pode fazer divisões com 0")
finally:
    print("Acabou amigo!")
# Out:
# Acabou amigo!
