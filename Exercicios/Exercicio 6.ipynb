# %% [markdown]
# # Exercicio 6

# %%
# Exercicio 1
divisionbell = open("txt/exemplo.txt")
divisionbell.read()
# Out:
# "Where were you\nWhen I was burned and broken?\nWhile the days slipped by\nFrom my window watching\n\nAnd where were you\nWhen I was hurt and I was helpless?\n'Cause the things you say\nAnd the things you do surround me\n\nWhile you were hanging yourself\nOn someone else's words\nDying to believe in what you heard\nI was staring straight into the shining Sun\n\nLost in thought and lost in time\nWhile the seeds of life\nAnd the seeds of change were planted\nOutside, the rain fell dark and slow\nWhile I pondered on this dangerous\nBut irresistible pastime\n\nI took a heavenly ride through our silence\nI knew the moment had arrived\nFor killing the past and coming back to life\n\nI took a heavenly ride through our silence\nI knew the waiting had begun\nAnd headed straight into the shining Sun\n\nPink Floyd, Coming Back to Life"

# %%
# Exercicio 2
with open("notas.txt", "w") as n:
    linha = input("Introduza as notas")
    n.write(linha)

# %%
# Exercicio 3
import os
os.listdir()
# Out:
# ['CadernoDeExercicio(5).ipynb',
#  'CadernoDeExercicios(1, 2).ipynb',
#  'CadernoDeExercicios(3).ipynb',
#  'CadernoDeExercicios(4).ipynb',
#  'CadernoDeExercicios(6).ipynb',
#  'Caderno_de_Exercicios_de_Programação.pdf',
#  'txt']

# %%
# Exercicio 4
with open("txt/origem.txt", "rb") as f:
    with open("txt/destino.txt", "wb") as w:
        w.write(f.read())

# %%
# Exercicio 5
with open("txt/exemplo.txt", "r") as r:
    print(len(r.readlines()))
# Out:
# 31

# %%
# Exercicio 6
import os
os.remove("destino.txt")

# %%
# Exercicio 7
import os
os.rename("exemplo.txt", "lyricspinkfloyd.txt")

# %%
# Exercicio 8
import os
os.makedirs("pasta")

# %%
# Exercicio 9
import os
os.removedirs("pasta")

# %%
# Exercicio 10
import os
os.path.exists("meu_diretorio")
# Out:
# False
